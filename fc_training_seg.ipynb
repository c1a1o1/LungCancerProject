# %%
import numpy as np
import os
INPUT_FOLDER = '../input/'

#os.environ["CUDA_DEVICE_ORDER"]=PCI_BUS_ID   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"

def load(npy):
    return np.load(os.path.join(INPUT_FOLDER,npy))

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, MaxPooling2D
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # After lung segmentation

# %%
data = load('train_features_seg.npy') # (1397, 224, 2048)
labels = load('y.npy')
#labels = keras.utils.np_utils.to_categorical(labels, 2)

# %%
data2=load('train_features.npy')

# %%
data2=np.mean(data2,axis=1)

# %%
data = np.mean(data, axis=1)

# %%
data.shape

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2048,),activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# 1000, 397 split
model.fit(data, labels, validation_split=397.0/1397.0, 
          nb_epoch=50, batch_size=32)
# Out:
# Train on 1000 samples, validate on 397 samples
# Epoch 1/50
# 1000/1000 [==============================] - 0s - loss: 0.6157 - acc: 0.7240 - val_loss: 0.5694 - val_acc: 0.7456
# Epoch 2/50
# 1000/1000 [==============================] - 0s - loss: 0.5899 - acc: 0.7370 - val_loss: 0.5660 - val_acc: 0.7456
# Epoch 3/50
# 1000/1000 [==============================] - 0s - loss: 0.5898 - acc: 0.7350 - val_loss: 0.7179 - val_acc: 0.7456
# Epoch 4/50
# 1000/1000 [==============================] - 0s - loss: 0.5971 - acc: 0.7380 - val_loss: 0.6479 - val_acc: 0.7103
# Epoch 5/50
# 1000/1000 [==============================] - 0s - loss: 0.5865 - acc: 0.7340 - val_loss: 0.6326 - val_acc: 0.7380
# Epoch 6/50
# 1000/1000 [==============================] - 0s - loss: 0.5870 - acc: 0.7270 - val_loss: 0.5683 - val_acc: 0.7456
# Epoch 7/50
# 1000/1000 [==============================] - 0s - loss: 0.5923 - acc: 0.7300 - val_loss: 0.5869 - val_acc: 0.7456
# Epoch 8/50
# ...

# %%
# 1000, 397 split
model.fit(data2, labels, validation_split=397.0/1397.0, 
          nb_epoch=50, batch_size=32)
# Out:
# Train on 1000 samples, validate on 397 samples
# Epoch 1/50
# 1000/1000 [==============================] - 3s - loss: 0.6171 - acc: 0.7190 - val_loss: 0.5767 - val_acc: 0.7481
# Epoch 2/50
# 1000/1000 [==============================] - 0s - loss: 0.5945 - acc: 0.7310 - val_loss: 0.6583 - val_acc: 0.7456
# Epoch 3/50
# 1000/1000 [==============================] - 0s - loss: 0.6012 - acc: 0.7130 - val_loss: 0.5593 - val_acc: 0.7456
# Epoch 4/50
# 1000/1000 [==============================] - 0s - loss: 0.5796 - acc: 0.7400 - val_loss: 0.5815 - val_acc: 0.7456
# Epoch 5/50
# 1000/1000 [==============================] - 0s - loss: 0.5968 - acc: 0.7300 - val_loss: 0.6153 - val_acc: 0.7330
# Epoch 6/50
#  - ETA: 0s - loss: 0.5979 - acc: 0.7083
# Epoch 7/50
# 1000/1000 [==============================] - 0s - loss: 0.5920 - acc: 0.7180 - val_loss: 0.5553 - val_acc: 0.7456
# Epoch 8/50
# ...

# %%
model.save('resnet50fc_seg.h5')

# %%
# 1000, 397 split
model.fit(data, labels, validation_split=397.0/1397.0, 
          nb_epoch=10, batch_size=32)

# %%
model = Sequential()
model.add(Flatten(input_shape=(224,2048)))
model.add(Dense(50))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# 1000, 397 split
model.fit(data, labels, validation_split=397.0/1397.0, 
          nb_epoch=5, batch_size=32)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(2048,)))
model.add(Activation('relu'))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 1000, 397 split
model.fit(data, labels, validation_split=397.0/1397.0, 
          nb_epoch=5, batch_size=32)
# Out:
# Train on 1000 samples, validate on 397 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s - loss: 0.6394 - acc: 0.7060 - val_loss: 0.5690 - val_acc: 0.7456
# Epoch 2/5
# 1000/1000 [==============================] - 0s - loss: 0.5886 - acc: 0.7380 - val_loss: 0.6121 - val_acc: 0.7280
# Epoch 3/5
# 1000/1000 [==============================] - 0s - loss: 0.5921 - acc: 0.7330 - val_loss: 0.6327 - val_acc: 0.7456
# Epoch 4/5
# 1000/1000 [==============================] - 0s - loss: 0.5870 - acc: 0.7370 - val_loss: 0.5893 - val_acc: 0.7456
# Epoch 5/5
# 1000/1000 [==============================] - 0s - loss: 0.5807 - acc: 0.7390 - val_loss: 0.5794 - val_acc: 0.7456

# %%
yhat = model.predict(data)

# %%
np.amax(yhat)

# %%
data = np.expand_dims(data, axis=3)
data.shape

# %%
model = Sequential()
model.add(Convolution2D(10, 4, 4, border_mode='valid', input_shape=(224,2048,1)))
model.add(MaxPooling2D(pool_size=(2, 2))) # (112,1024,10)
model.add(Flatten())
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# 1000, 397 split
model.fit(data, labels, validation_split=397.0/1397.0, 
          nb_epoch=5, batch_size=16)
